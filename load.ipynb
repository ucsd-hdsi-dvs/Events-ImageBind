# %%
import json
file_path = '/eastdata/datasets/N-Caltech101/Caltech101_classnames.json'

# Open the file and load its contents
with open(file_path, 'r') as file:
    class_names = json.load(file)

# %%
class_names
# Out:
# {'trilobite': 0,
#  'scissors': 1,
#  'cannon': 2,
#  'Faces_easy': 3,
#  'strawberry': 4,
#  'pigeon': 5,
#  'gerenuk': 6,
#  'Motorbikes': 7,
#  'sea_horse': 8,
#  'crocodile': 9,
#  'ceiling_fan': 10,
#  'flamingo': 11,
#  'pagoda': 12,
#  'stop_sign': 13,
#  'cup': 14,
#  'mandolin': 15,
#  'electric_guitar': 16,
#  'revolver': 17,
#  'brain': 18,
#  'Leopards': 19,
#  'dolphin': 20,
#  'tick': 21,
#  'crocodile_head': 22,
#  'camera': 23,
#  'accordion': 24,
#  'butterfly': 25,
#  'hawksbill': 26,
#  'rooster': 27,
#  'joshua_tree': 28,
#  'barrel': 29,
#  'kangaroo': 30,
#  'chair': 31,
#  'buddha': 32,
#  'grand_piano': 33,
#  'lotus': 34,
#  'brontosaurus': 35,
#  'binocular': 36,
#  'laptop': 37,
#  'metronome': 38,
#  'euphonium': 39,
#  'garfield': 40,
#  'okapi': 41,
#  'dollar_bill': 42,
#  'wheelchair': 43,
#  'bonsai': 44,
#  'snoopy': 45,
#  'airplanes': 46,
#  'minaret': 47,
#  'ferry': 48,
#  'wild_cat': 49,
#  'cougar_face': 50,
#  'dalmatian': 51,
# ...

# %%
label_str='fish'

# %%
'A sketch image of a ' + label_str
# Out:
# 'A sketch image of a fish'
